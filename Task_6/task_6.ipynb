# %% [markdown]
# TASK 6: MACHINE LEARNING MODEL DEPLOYMENT
#
# Perform the following:
#
#     Load the final trained machine learning model into a deployment environment.
#
#     Develop a user-friendly interface (e.g., Shiny, Streamlit, Flask, or Dash) for making predictions.
#
#     Allow users to input predictor values and generate real-time predictions.
#
#     Display prediction probabilities, confidence scores, or risk categories where appropriate.
#
#     Integrate Explainable AI (e.g., SHAP or DALEX) to explain individual predictions.
#
#     Optional: Add AI Assistant via free API key (https://github.com/public-apis/public-apis#machine-learning)
#
#     Present the deployed application link.
#
# Deliverable: A live, publicly accessible deployment link and a brief guide on how to use the application.

# %% [markdown]
# ## Completed deployment assets\n\nA Streamlit customer-churn prediction application has been created in `deployment/app.py`. It loads the portable `deployment/churn_model_bundle.joblib` artifact, which reproduces the Task 5 model preprocessing and Logistic Regression settings.\n\nThe interface accepts all final-model features and displays a churn prediction, probability, confidence score, risk category, and individual SHAP contributions. See `TASK_6_DEPLOYMENT_GUIDE.md` for local-use and Streamlit Community Cloud publishing instructions.

# %%
# Run from a terminal in the project root:\n# python -m pip install -r deployment/requirements.txt\n# python deployment/build_model.py\n# streamlit run deployment/app.py
